# %%
import pandas as pd
import numpy as np

# %%
TS_similarity= pd.read_csv("TS_Similarity_223.csv")
TS_similarity
# Out:
#                                               smiles_r  ts_nearest
# 0       C#Cc1cccc(N=c2[nH]cnc3cc(OCCOC)c(OCCOC)cc23)c1    0.246319
# 1                                   CC1OC1[P](=O)(=O)O    0.235178
# 2                   CC(C)CC(N(C)C)C1(c2ccc(Cl)cc2)CCC1    0.244207
# 3    COCCCOc1cc(CC(CC(N)C(O)CC(C(=O)NCC(C)(C)C(N)=O...    0.268495
# 4                   CNC1CCC(c2ccc(Cl)c(Cl)c2)c2ccccc21    0.238541
# ..                                                 ...         ...
# 218                       ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl    0.088813
# 219       Oc1c(C2=CCC(c3ccc(Cl)cc3)CC2)c(O)c2ccccc2c1O    0.203165
# 220                            C=Cc1ccc(S(=O)(=O)O)cc1    0.205958
# 221                               OCC(O)c1oc(O)c(O)c1O    0.230432
# 222           CC1(Cn2ccnn2)C(C(=O)O)N2C(=O)CC2S1(=O)=O    0.250146
#
# [223 rows x 2 columns]

# %%
test_data_heldouttest= pd.read_csv("Heldout_test_predictions_earlydetection.csv")
test_data_heldouttest
# Out:
#                                               smiles_r  TOXICITY  Source_rank  \
# 0       C#Cc1cccc(N=c2[nH]cnc3cc(OCCOC)c(OCCOC)cc23)c1         1            1
# 1                                   CC1OC1[P](=O)(=O)O         1            1
# 2                   CC(C)CC(N(C)C)C1(c2ccc(Cl)cc2)CCC1         1            1
# 3    COCCCOc1cc(CC(CC(N)C(O)CC(C(=O)NCC(C)(C)C(N)=O...         1            1
# 4                   CNC1CCC(c2ccc(Cl)c(Cl)c2)c2ccccc21         1            1
# ..                                                 ...       ...          ...
# 218                       ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl         0            1
# 219       Oc1c(C2=CCC(c3ccc(Cl)cc3)CC2)c(O)c2ccccc2c1O         0            1
# 220                            C=Cc1ccc(S(=O)(=O)O)cc1         0            1
# 221                               OCC(O)c1oc(O)c(O)c1O         0            1
# 222           CC1(Cn2ccnn2)C(C(=O)O)N2C(=O)CC2S1(=O)=O         0            1
#
#                                              Source  Data  all_features_preds  \
# 0                       DILIst Classification  Oral  DILI                   1
# 1                       DILIst Classification  Oral  DILI                   0
# 2                       DILIst Classification  Oral  DILI                   0
# 3                       DILIst Classification  Oral  DILI                   0
# 4                       DILIst Classification  Oral  DILI                   1
# ..                                              ...   ...                 ...
# 218                  DILIst Classification  Topical  DILI                   0
# 219                     DILIst Classification  Oral  DILI                   1
# 220                     DILIst Classification  Oral  DILI                   1
# 221              DILIst Classification  Intravenous  DILI                   0
# 222  DILIst Classification  Intravenous; Parenteral  DILI                   1
#
#      all_features_proba  mfp_maccs_preds  mfp_maccs_proba  \
# 0              0.728152                1         0.754960
# 1              0.581439                0         0.535236
# 2              0.576492                0         0.402824
# 3              0.463513                0         0.551885
# 4              0.714039                1         0.630923
# ..                  ...              ...              ...
# 218            0.564779                1         0.701466
# 219            0.775135                1         0.647040
# 220            0.753467                1         0.858123
# 221            0.486452                0         0.380578
# 222            0.705021                1         0.745773
#
#      mfp_earlydetections  allfeatures_earlydetections
# 0                  False                        False
# 1                  False                        False
# 2                  False                        False
# 3                  False                        False
# 4                  False                        False
# ..                   ...                          ...
# 218                False                        False
# 219                False                        False
# 220                 True                        False
# 221                False                        False
# 222                False                        False
#
# [223 rows x 11 columns]

# %%
test_data_heldouttest = pd.merge(test_data_heldouttest, TS_similarity)
test_data_heldouttest
# Out:
#                                               smiles_r  TOXICITY  Source_rank  \
# 0       C#Cc1cccc(N=c2[nH]cnc3cc(OCCOC)c(OCCOC)cc23)c1         1            1
# 1                                   CC1OC1[P](=O)(=O)O         1            1
# 2                   CC(C)CC(N(C)C)C1(c2ccc(Cl)cc2)CCC1         1            1
# 3    COCCCOc1cc(CC(CC(N)C(O)CC(C(=O)NCC(C)(C)C(N)=O...         1            1
# 4                   CNC1CCC(c2ccc(Cl)c(Cl)c2)c2ccccc21         1            1
# ..                                                 ...       ...          ...
# 218                       ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl         0            1
# 219       Oc1c(C2=CCC(c3ccc(Cl)cc3)CC2)c(O)c2ccccc2c1O         0            1
# 220                            C=Cc1ccc(S(=O)(=O)O)cc1         0            1
# 221                               OCC(O)c1oc(O)c(O)c1O         0            1
# 222           CC1(Cn2ccnn2)C(C(=O)O)N2C(=O)CC2S1(=O)=O         0            1
#
#                                              Source  Data  all_features_preds  \
# 0                       DILIst Classification  Oral  DILI                   1
# 1                       DILIst Classification  Oral  DILI                   0
# 2                       DILIst Classification  Oral  DILI                   0
# 3                       DILIst Classification  Oral  DILI                   0
# 4                       DILIst Classification  Oral  DILI                   1
# ..                                              ...   ...                 ...
# 218                  DILIst Classification  Topical  DILI                   0
# 219                     DILIst Classification  Oral  DILI                   1
# 220                     DILIst Classification  Oral  DILI                   1
# 221              DILIst Classification  Intravenous  DILI                   0
# 222  DILIst Classification  Intravenous; Parenteral  DILI                   1
#
#      all_features_proba  mfp_maccs_preds  mfp_maccs_proba  \
# 0              0.728152                1         0.754960
# 1              0.581439                0         0.535236
# 2              0.576492                0         0.402824
# 3              0.463513                0         0.551885
# 4              0.714039                1         0.630923
# ..                  ...              ...              ...
# 218            0.564779                1         0.701466
# 219            0.775135                1         0.647040
# 220            0.753467                1         0.858123
# 221            0.486452                0         0.380578
# 222            0.705021                1         0.745773
#
#      mfp_earlydetections  allfeatures_earlydetections  ts_nearest
# 0                  False                        False    0.246319
# 1                  False                        False    0.235178
# 2                  False                        False    0.244207
# 3                  False                        False    0.268495
# 4                  False                        False    0.238541
# ..                   ...                          ...         ...
# 218                False                        False    0.088813
# 219                False                        False    0.203165
# 220                 True                        False    0.205958
# 221                False                        False    0.230432
# 222                False                        False    0.250146
#
# [223 rows x 12 columns]

# %%
test_data_heldouttest_5=test_data_heldouttest[test_data_heldouttest["TOXICITY"]==1].reset_index(drop=True)
test_data_heldouttest_5
# Out:
#                                               smiles_r  TOXICITY  Source_rank  \
# 0       C#Cc1cccc(N=c2[nH]cnc3cc(OCCOC)c(OCCOC)cc23)c1         1            1
# 1                                   CC1OC1[P](=O)(=O)O         1            1
# 2                   CC(C)CC(N(C)C)C1(c2ccc(Cl)cc2)CCC1         1            1
# 3    COCCCOc1cc(CC(CC(N)C(O)CC(C(=O)NCC(C)(C)C(N)=O...         1            1
# 4                   CNC1CCC(c2ccc(Cl)c(Cl)c2)c2ccccc21         1            1
# ..                                                 ...       ...          ...
# 151                         c1cnc2cc3c(cc2n1)C1CNCC3C1         1            1
# 152         CC1(C)OC2COC3(COS(N)(=O)=O)OC(C)(C)OC3C2O1         1            1
# 153              O=C(O)c1ccc[nH]c1=Nc1cccc(C(F)(F)F)c1         1            1
# 154   CCN(CC)C(=O)C(C#N)=Cc1cc(O)c(O)c([N+](=O)[O-])c1         1            1
# 155              CCOC(=O)Nc1ccc(=NCc2ccc(F)cc2)[nH]c1N         1            1
#
#                           Source  Data  all_features_preds  \
# 0    DILIst Classification  Oral  DILI                   1
# 1    DILIst Classification  Oral  DILI                   0
# 2    DILIst Classification  Oral  DILI                   0
# 3    DILIst Classification  Oral  DILI                   0
# 4    DILIst Classification  Oral  DILI                   1
# ..                           ...   ...                 ...
# 151  DILIst Classification  Oral  DILI                   0
# 152  DILIst Classification  Oral  DILI                   1
# 153      DILIst Classification    DILI                   1
# 154  DILIst Classification  Oral  DILI                   1
# 155      DILIst Classification    DILI                   1
#
#      all_features_proba  mfp_maccs_preds  mfp_maccs_proba  \
# 0              0.728152                1         0.754960
# 1              0.581439                0         0.535236
# 2              0.576492                0         0.402824
# 3              0.463513                0         0.551885
# 4              0.714039                1         0.630923
# ..                  ...              ...              ...
# 151            0.608723                1         0.672106
# 152            0.655642                0         0.449841
# 153            0.834780                1         0.918406
# 154            0.796836                1         0.656739
# 155            0.836141                1         0.681897
#
#      mfp_earlydetections  allfeatures_earlydetections  ts_nearest
# 0                  False                        False    0.246319
# 1                  False                        False    0.235178
# 2                  False                        False    0.244207
# 3                  False                        False    0.268495
# 4                  False                        False    0.238541
# ..                   ...                          ...         ...
# 151                False                        False    0.167572
# 152                False                        False    0.131900
# 153                 True                         True    0.301828
# 154                False                         True    0.267009
# 155                False                         True    0.238613
#
# [156 rows x 12 columns]

# %%
k1= test_data_heldouttest_5[test_data_heldouttest_5["mfp_earlydetections"] == True][["smiles_r",  "ts_nearest"]]
k1["Model"] = "Using Structural Features"
k1
# Out:
#                                               smiles_r  ts_nearest  \
# 6    Cc1ccc(-n2[nH]c(C)c(N=Nc3cccc(-c4cccc(C(=O)O)c...    0.231561
# 7    CC(=O)Oc1cccc2c1C(=O)c1c(OC(C)=O)cc(C(=O)O)cc1...    0.328127
# 9    CC(C)(O)c1ccccc1CCC(SCC1(CC(=O)O)CC1)c1cccc(C=...    0.209755
# 10                    Cc1oncc1C(=O)Nc1ccc(C(F)(F)F)cc1    0.257116
# 26   Cc1ccc(-c2cc(C(F)(F)F)nn2-c2ccc(S(N)(=O)=O)cc2...    0.257754
# 37                        CC1=NS(=O)(=O)c2cc(Cl)ccc2N1    0.283964
# 39                      Cc1[nH]c(=O)c(C#N)cc1-c1ccncc1    0.202490
# 58   CCOc1cc(CC(=O)NC(CC(C)C)c2ccccc2N2CCCCC2)ccc1C...    0.253570
# 64                 Nc1c(CC(=O)O)cccc1C(=O)c1ccc(Br)cc1    0.323735
# 88                     Cc1ccc(C)c(OCCCC(C)(C)C(=O)O)c1    0.267989
# 111            Cc1nc(-c2ccc(OCC(C)C)c(C#N)c2)sc1C(=O)O    0.253055
# 113                   O=C(O)COc1nn(Cc2ccccc2)c2ccccc12    0.273382
# 114  CS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccccn3)c2)...    0.273160
# 119             CCN(CC)CCNc1ccc(CO)c2sc3ccccc3c(=O)c12    0.255209
# 121  CC1=C(CC(=O)O)c2cc(F)ccc2C1=Cc1ccc([S+](C)[O-]...    0.257062
# 125                         Cc1cc(=O)n(-c2ccccc2)[nH]1    0.280961
# 127              O=C(O)CCc1nc(-c2ccccc2)c(-c2ccccc2)o1    0.274940
# 133                     O=C1c2ccccc2C(=O)C1c1ccc(F)cc1    0.233737
# 134   C=C(c1ccc(C(=O)O)cc1)c1cc2c(cc1C)C(C)(C)CCC2(C)C    0.284334
# 138      Cc1nc([N+](=O)[O-])cn1-c1ccc([N+](=O)[O-])cc1    0.255578
# 141                                S=C=Nc1cccc2ccccc12    0.207786
# 144                             Cc1cc(Br)c(O)c2ncccc12    0.242856
# 153              O=C(O)c1ccc[nH]c1=Nc1cccc(C(F)(F)F)c1    0.301828
#
#                          Model
# 6    Using Structural Features
# 7    Using Structural Features
# 9    Using Structural Features
# 10   Using Structural Features
# 26   Using Structural Features
# 37   Using Structural Features
# 39   Using Structural Features
# 58   Using Structural Features
# 64   Using Structural Features
# 88   Using Structural Features
# 111  Using Structural Features
# 113  Using Structural Features
# 114  Using Structural Features
# 119  Using Structural Features
# 121  Using Structural Features
# 125  Using Structural Features
# 127  Using Structural Features
# 133  Using Structural Features
# 134  Using Structural Features
# 138  Using Structural Features
# 141  Using Structural Features
# 144  Using Structural Features
# 153  Using Structural Features

# %%
len(k1)
# Out:
# 23

# %%
k2= test_data_heldouttest_5[test_data_heldouttest_5["allfeatures_earlydetections"] == True][["smiles_r",  "ts_nearest"]]
k2["Model"] = "DILIPredictor"
k2
# Out:
#                                               smiles_r  ts_nearest  \
# 6    Cc1ccc(-n2[nH]c(C)c(N=Nc3cccc(-c4cccc(C(=O)O)c...    0.231561
# 7    CC(=O)Oc1cccc2c1C(=O)c1c(OC(C)=O)cc(C(=O)O)cc1...    0.328127
# 8                             NS(=O)(=O)Cc1noc2ccccc12    0.268261
# 10                    Cc1oncc1C(=O)Nc1ccc(C(F)(F)F)cc1    0.257116
# 23                     O=C(c1ccccc1)c1ccc2n1CCC2C(=O)O    0.290493
# 31       CNC(=O)c1ccccc1Sc1ccc2c(C=Cc3ccccn3)[nH]nc2c1    0.189220
# 32    COc1cc(NS(C)(=O)=O)ccc1N=c1c2ccccc2[nH]c2ccccc12    0.262351
# 34             Cn1cnc([N+](=O)[O-])c1Sc1ncnc2[nH]cnc12    0.215050
# 35       Cc1cccc(N=c2cc[nH]cc2S(=O)(=O)NC(=O)NC(C)C)c1    0.236676
# 39                      Cc1[nH]c(=O)c(C#N)cc1-c1ccncc1    0.202490
# 64                 Nc1c(CC(=O)O)cccc1C(=O)c1ccc(Br)cc1    0.323735
# 74   O=C(NC(Cc1cc(=O)[nH]c2ccccc12)C(=O)O)c1ccc(Cl)cc1    0.289464
# 95   Cc1ccc(N=c2nc(N(C)c3ccc4c(C)n(C)nc4c3)cc[nH]2)...    0.204598
# 111            Cc1nc(-c2ccc(OCC(C)C)c(C#N)c2)sc1C(=O)O    0.253055
# 113                   O=C(O)COc1nn(Cc2ccccc2)c2ccccc12    0.273382
# 117         COc1ccc2c(C(=S)N(C)CC(=O)O)cccc2c1C(F)(F)F    0.258385
# 121  CC1=C(CC(=O)O)c2cc(F)ccc2C1=Cc1ccc([S+](C)[O-]...    0.257062
# 127              O=C(O)CCc1nc(-c2ccccc2)c(-c2ccccc2)o1    0.274940
# 129         COc1cc2c(c3oc(=O)c4c(c13)CCC4=O)C1C=COC1O2    0.181823
# 131                        CC(c1cc2ccccc2s1)N(O)C(N)=O    0.261966
# 133                     O=C1c2ccccc2C(=O)C1c1ccc(F)cc1    0.233737
# 138      Cc1nc([N+](=O)[O-])cn1-c1ccc([N+](=O)[O-])cc1    0.255578
# 153              O=C(O)c1ccc[nH]c1=Nc1cccc(C(F)(F)F)c1    0.301828
# 154   CCN(CC)C(=O)C(C#N)=Cc1cc(O)c(O)c([N+](=O)[O-])c1    0.267009
# 155              CCOC(=O)Nc1ccc(=NCc2ccc(F)cc2)[nH]c1N    0.238613
#
#              Model
# 6    DILIPredictor
# 7    DILIPredictor
# 8    DILIPredictor
# 10   DILIPredictor
# 23   DILIPredictor
# 31   DILIPredictor
# 32   DILIPredictor
# 34   DILIPredictor
# 35   DILIPredictor
# 39   DILIPredictor
# 64   DILIPredictor
# 74   DILIPredictor
# 95   DILIPredictor
# 111  DILIPredictor
# 113  DILIPredictor
# 117  DILIPredictor
# 121  DILIPredictor
# 127  DILIPredictor
# 129  DILIPredictor
# 131  DILIPredictor
# 133  DILIPredictor
# 138  DILIPredictor
# 153  DILIPredictor
# 154  DILIPredictor
# 155  DILIPredictor

# %%
len(k2)
# Out:
# 25

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statannotations.Annotator import Annotator

# %%
k = pd.concat([k1, k2]).reset_index(drop=True)
k
# Out:
#                                              smiles_r  ts_nearest  \
# 0   Cc1ccc(-n2[nH]c(C)c(N=Nc3cccc(-c4cccc(C(=O)O)c...    0.231561
# 1   CC(=O)Oc1cccc2c1C(=O)c1c(OC(C)=O)cc(C(=O)O)cc1...    0.328127
# 2   CC(C)(O)c1ccccc1CCC(SCC1(CC(=O)O)CC1)c1cccc(C=...    0.209755
# 3                    Cc1oncc1C(=O)Nc1ccc(C(F)(F)F)cc1    0.257116
# 4   Cc1ccc(-c2cc(C(F)(F)F)nn2-c2ccc(S(N)(=O)=O)cc2...    0.257754
# 5                        CC1=NS(=O)(=O)c2cc(Cl)ccc2N1    0.283964
# 6                      Cc1[nH]c(=O)c(C#N)cc1-c1ccncc1    0.202490
# 7   CCOc1cc(CC(=O)NC(CC(C)C)c2ccccc2N2CCCCC2)ccc1C...    0.253570
# 8                 Nc1c(CC(=O)O)cccc1C(=O)c1ccc(Br)cc1    0.323735
# 9                     Cc1ccc(C)c(OCCCC(C)(C)C(=O)O)c1    0.267989
# 10            Cc1nc(-c2ccc(OCC(C)C)c(C#N)c2)sc1C(=O)O    0.253055
# 11                   O=C(O)COc1nn(Cc2ccccc2)c2ccccc12    0.273382
# 12  CS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccccn3)c2)...    0.273160
# 13             CCN(CC)CCNc1ccc(CO)c2sc3ccccc3c(=O)c12    0.255209
# 14  CC1=C(CC(=O)O)c2cc(F)ccc2C1=Cc1ccc([S+](C)[O-]...    0.257062
# 15                         Cc1cc(=O)n(-c2ccccc2)[nH]1    0.280961
# 16              O=C(O)CCc1nc(-c2ccccc2)c(-c2ccccc2)o1    0.274940
# 17                     O=C1c2ccccc2C(=O)C1c1ccc(F)cc1    0.233737
# 18   C=C(c1ccc(C(=O)O)cc1)c1cc2c(cc1C)C(C)(C)CCC2(C)C    0.284334
# 19      Cc1nc([N+](=O)[O-])cn1-c1ccc([N+](=O)[O-])cc1    0.255578
# 20                                S=C=Nc1cccc2ccccc12    0.207786
# 21                             Cc1cc(Br)c(O)c2ncccc12    0.242856
# 22              O=C(O)c1ccc[nH]c1=Nc1cccc(C(F)(F)F)c1    0.301828
# 23  Cc1ccc(-n2[nH]c(C)c(N=Nc3cccc(-c4cccc(C(=O)O)c...    0.231561
# 24  CC(=O)Oc1cccc2c1C(=O)c1c(OC(C)=O)cc(C(=O)O)cc1...    0.328127
# 25                           NS(=O)(=O)Cc1noc2ccccc12    0.268261
# 26                   Cc1oncc1C(=O)Nc1ccc(C(F)(F)F)cc1    0.257116
# 27                    O=C(c1ccccc1)c1ccc2n1CCC2C(=O)O    0.290493
# 28      CNC(=O)c1ccccc1Sc1ccc2c(C=Cc3ccccn3)[nH]nc2c1    0.189220
# 29   COc1cc(NS(C)(=O)=O)ccc1N=c1c2ccccc2[nH]c2ccccc12    0.262351
# 30            Cn1cnc([N+](=O)[O-])c1Sc1ncnc2[nH]cnc12    0.215050
# 31      Cc1cccc(N=c2cc[nH]cc2S(=O)(=O)NC(=O)NC(C)C)c1    0.236676
# 32                     Cc1[nH]c(=O)c(C#N)cc1-c1ccncc1    0.202490
# 33                Nc1c(CC(=O)O)cccc1C(=O)c1ccc(Br)cc1    0.323735
# 34  O=C(NC(Cc1cc(=O)[nH]c2ccccc12)C(=O)O)c1ccc(Cl)cc1    0.289464
# 35  Cc1ccc(N=c2nc(N(C)c3ccc4c(C)n(C)nc4c3)cc[nH]2)...    0.204598
# 36            Cc1nc(-c2ccc(OCC(C)C)c(C#N)c2)sc1C(=O)O    0.253055
# 37                   O=C(O)COc1nn(Cc2ccccc2)c2ccccc12    0.273382
# 38         COc1ccc2c(C(=S)N(C)CC(=O)O)cccc2c1C(F)(F)F    0.258385
# 39  CC1=C(CC(=O)O)c2cc(F)ccc2C1=Cc1ccc([S+](C)[O-]...    0.257062
# 40              O=C(O)CCc1nc(-c2ccccc2)c(-c2ccccc2)o1    0.274940
# 41         COc1cc2c(c3oc(=O)c4c(c13)CCC4=O)C1C=COC1O2    0.181823
# 42                        CC(c1cc2ccccc2s1)N(O)C(N)=O    0.261966
# 43                     O=C1c2ccccc2C(=O)C1c1ccc(F)cc1    0.233737
# 44      Cc1nc([N+](=O)[O-])cn1-c1ccc([N+](=O)[O-])cc1    0.255578
# 45              O=C(O)c1ccc[nH]c1=Nc1cccc(C(F)(F)F)c1    0.301828
# 46   CCN(CC)C(=O)C(C#N)=Cc1cc(O)c(O)c([N+](=O)[O-])c1    0.267009
# 47              CCOC(=O)Nc1ccc(=NCc2ccc(F)cc2)[nH]c1N    0.238613
#
#                         Model
# 0   Using Structural Features
# 1   Using Structural Features
# 2   Using Structural Features
# 3   Using Structural Features
# 4   Using Structural Features
# 5   Using Structural Features
# 6   Using Structural Features
# 7   Using Structural Features
# 8   Using Structural Features
# 9   Using Structural Features
# 10  Using Structural Features
# 11  Using Structural Features
# 12  Using Structural Features
# 13  Using Structural Features
# 14  Using Structural Features
# 15  Using Structural Features
# 16  Using Structural Features
# 17  Using Structural Features
# 18  Using Structural Features
# 19  Using Structural Features
# 20  Using Structural Features
# 21  Using Structural Features
# 22  Using Structural Features
# 23              DILIPredictor
# 24              DILIPredictor
# 25              DILIPredictor
# 26              DILIPredictor
# 27              DILIPredictor
# 28              DILIPredictor
# 29              DILIPredictor
# 30              DILIPredictor
# 31              DILIPredictor
# 32              DILIPredictor
# 33              DILIPredictor
# 34              DILIPredictor
# 35              DILIPredictor
# 36              DILIPredictor
# 37              DILIPredictor
# 38              DILIPredictor
# 39              DILIPredictor
# 40              DILIPredictor
# 41              DILIPredictor
# 42              DILIPredictor
# 43              DILIPredictor
# 44              DILIPredictor
# 45              DILIPredictor
# 46              DILIPredictor
# 47              DILIPredictor

# %%
k.groupby("Model").describe()
# Out:
#                           ts_nearest                                          \
#                                count      mean       std       min       25%
# Model
# DILIPredictor                   25.0  0.254261  0.037673  0.181823  0.233737
# Using Structural Features       23.0  0.261302  0.032448  0.202490  0.247955
#
#
#                                 50%       75%       max
# Model
# DILIPredictor              0.257116  0.273382  0.328127
# Using Structural Features  0.257116  0.277950  0.328127

# %%
fig, ax = plt.subplots(figsize=(10, 5), dpi=300)
sns.kdeplot(x='ts_nearest', data=k, hue='Model', common_norm=False)
plt.title("Kernel Density Function")
# Out:
# Text(0.5, 1.0, 'Kernel Density Function')

# %%
plt.figure(dpi= 200)
sns.displot(k, x="ts_nearest", hue="Model", element="step", height = 5)
